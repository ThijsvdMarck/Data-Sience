# %%
import pickle
# Load the .pkl file
with open('cars.pkl', 'rb') as file:
    cars_data = pickle.load(file)

cars_data.head()
# Out:
#   kenteken voertuigsoort        merk  handelsbenaming vervaldatum_apk  \
# 0   Z394SB  Personenauto         BMW     IX1 EDRIVE20        20280607
# 1   Z726RX  Personenauto  VOLKSWAGEN  ID.3 PRO 150 KW        20270310
# 2   Z778RZ  Personenauto         BYD           ATTO 3        20280614
# 3   Z780RX  Personenauto        JEEP          AVENGER        20280618
# 4   Z795RX  Personenauto        JEEP          AVENGER        20280607
#
#   datum_tenaamstelling    inrichting massa_ledig_voertuig massa_rijklaar  \
# 0             20240607  stationwagen                 1840           1940
# 1                  NaN  stationwagen                 1713           1813
# 2             20240614           MPV                 1725           1825
# 3             20240618           MPV                 1495           1595
# 4             20240607           MPV                 1495           1595
#
#   datum_eerste_toelating  ... wielbasis export_indicator  \
# ...

# %%
import pandas as pd
# Load the .pkl file
cars1 = pd.read_pickle('cars.pkl')
cars1.head()
# Out:
#   kenteken voertuigsoort        merk  handelsbenaming vervaldatum_apk  \
# 0   Z394SB  Personenauto         BMW     IX1 EDRIVE20        20280607
# 1   Z726RX  Personenauto  VOLKSWAGEN  ID.3 PRO 150 KW        20270310
# 2   Z778RZ  Personenauto         BYD           ATTO 3        20280614
# 3   Z780RX  Personenauto        JEEP          AVENGER        20280618
# 4   Z795RX  Personenauto        JEEP          AVENGER        20280607
#
#   datum_tenaamstelling    inrichting massa_ledig_voertuig massa_rijklaar  \
# 0             20240607  stationwagen                 1840           1940
# 1                  NaN  stationwagen                 1713           1813
# 2             20240614           MPV                 1725           1825
# 3             20240618           MPV                 1495           1595
# 4             20240607           MPV                 1495           1595
#
#   datum_eerste_toelating  ... wielbasis export_indicator  \
# ...
